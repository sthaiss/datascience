# %% [markdown]
# ## 🧪 **Métricas de Avaliação – Modelos de Regressão**
#
# Em regressão, o modelo prevê **valores contínuos**, e as métricas servem para medir **o quão próximo o valor previsto está do valor real**. Aqui estão as principais:
#
# ---
#
# ### 📉 **MAE – Mean Absolute Error**
#
# * **Interpretação**: Média dos **erros absolutos** entre predições e valores reais.
#   $MAE = \frac{1}{n} \sum |y_{real} - y_{previsto}|$
# * **Exemplo prático**: Se o MAE for 5, o modelo erra em média 5 unidades por predição.
# * **Limitação**: Não penaliza grandes erros com mais severidade.
# * **Usar quando**: Erros **têm impacto linear** e você quer uma métrica fácil de interpretar.
#
# ---
#
# ### 📈 **MSE – Mean Squared Error**
#
# * **Interpretação**: Média dos **erros quadráticos**. Penaliza mais os grandes erros.
#   $MSE = \frac{1}{n} \sum (y_{real} - y_{previsto})^2$
# * **Exemplo prático**: Um erro de 10 vale 100, um erro de 1 vale 1 — grandes erros impactam muito.
# * **Limitação**: Difícil de interpretar por estar em unidades ao quadrado.
# * **Usar quando**: Você quer **penalizar mais fortemente os erros grandes**.
#
# ---
#
# ### 🧮 **RMSE – Root Mean Squared Error**
#
# * **Interpretação**: Raiz quadrada do MSE. Fica na **mesma unidade da variável-alvo**.
#   $RMSE = \sqrt{MSE}$
# * **Exemplo prático**: Se o RMSE for 12, o erro médio esperado por predição é ≈ 12 unidades.
# * **Limitação**: Ainda sensível a outliers.
# * **Usar quando**: Quer **comparar erros em escala real** e ainda penalizar grandes erros.
#
# ---
#
# ### 📊 **R² – Coeficiente de Determinação**
#
# * **Interpretação**: Mede a **proporção da variância explicada pelo modelo**.
#   $R^2 = 1 - \frac{Soma~dos~Erros~do~Modelo}{Soma~dos~Erros~do~Modelo~nulo}$
# * **Exemplo prático**: R² = 0.80 → 80% da variância dos dados foi explicada pelo modelo.
# * **Limitação**: Pode ser enganoso se o modelo for ruim ou se os dados forem não lineares.
# * **Usar quando**: Quer avaliar **o quão bem o modelo explica os dados** como um todo.
#
# ---
#
# ## 📌 **Resumo prático: qual usar quando?**
#
# | Situação                          | Métrica recomendada |
# | --------------------------------- | ------------------- |
# | Interpretabilidade simples        | **MAE**             |
# | Penalizar grandes erros           | **MSE**, **RMSE**   |
# | Comparar desempenho entre modelos | **RMSE**, **R²**    |
# | Ver explicabilidade global        | **R²**              |
#
# ---
#
# 💡 **Dica extra**:
#
# > Olhar MAE para entender o erro médio real, RMSE quando grandes erros importam mais, e R² para ver o quanto o modelo está explicando do problema como um todo.
